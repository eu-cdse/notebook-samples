# %%
from typing import List, Optional
import requests
import geopandas as gpd
from shapely.geometry import Polygon
import folium

# %%
class MapTiles:
    """
    Fetch the footprints for given satellite scenes.

    This class handles the odata queries for the satellite scenes
    and builds an output geospatial file.
    """

    def __init__(
        self,
        input_products: Optional[list] = None,
    ):
        if isinstance(input_products, str):
            self.input_products = [input_products]
        elif isinstance(input_products, list):
            self.input_products = input_products
        else:
            raise ValueError("input_products must be a list or a string")
        self.catalog_entries = None
        self.no_data = []

    def query_catalog(self) -> List:
        if not self.input_products:
            raise ValueError("No input data provided.")
        json_response = []
        for product in self.input_products:
            try:
                json = requests.get(
                    f"https://catalogue.dataspace.copernicus.eu/odata/v1/Products?$filter=startswith(Name, '{product}')"
                ).json()
                if json:
                    json_response.append(json["value"][0])
                else:
                    self.no_data.append(product)
            except Exception as e:
                raise ValueError(f"Failed to query the catalogue: {e}")

            gdf = gpd.GeoDataFrame(json_response)
            gdf.set_geometry(
                gdf["GeoFootprint"].apply(lambda x: Polygon(x["coordinates"][0])),
                inplace=True,
            )
            gdf.set_crs(epsg=4326, inplace=True)
            self.catalog_entries = gdf

    def plot_footprints(self):
        if self.catalog_entries is None:
            raise ValueError("No catalog entries found.")
        # Explore the GeoDataFrame, visualizing the 'area' column with a specified colormap
        reprojected_gdf = self.catalog_entries.to_crs(epsg=4326)
        m = folium.Map()
        fit_bounds = reprojected_gdf.total_bounds.tolist()
        m.fit_bounds([[fit_bounds[1], fit_bounds[0]], [fit_bounds[3], fit_bounds[2]]])
        folium.GeoJson(reprojected_gdf).add_to(m)

        return m

# %%
# Sentinel 2
s2_single_scene = "S2B_MSIL1C_20250213T100029_N0511_R122_T33TVN_20250213T115442"

mt = MapTiles(s2_single_scene)
print(mt.input_products)

mt.query_catalog()

mt.plot_footprints()
# Out:
# ['S2B_MSIL1C_20250213T100029_N0511_R122_T33TVN_20250213T115442']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_180d51c6386d09835c2551aaaf6c87d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_180d51c6386d09835c2551aaaf6c87d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_180d51c6386d09835c2551aaaf6c87d1 = L.map(
#                 &quot;map_180d51c6386d09835c2551aaaf6c87d1&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f304ccc17dddec209b22a606aba7a3ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f304ccc17dddec209b22a606aba7a3ef.addTo(map_180d51c6386d09835c2551aaaf6c87d1);
#
#
#             map_180d51c6386d09835c2551aaaf6c87d1.fitBounds(
#                 [[46.858175957972115, 13.662865290445673], [47.85362771191058, 15.130470361916801]],
#                 {}
#             );
#
#
#
#         function geo_json_da943d7a2b571cdf765a2ac0e87d0c53_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_da943d7a2b571cdf765a2ac0e87d0c53 = L.geoJson(null, {
#                 onEachFeature: geo_json_da943d7a2b571cdf765a2ac0e87d0c53_onEachFeature,
#
#         });
#
#         function geo_json_da943d7a2b571cdf765a2ac0e87d0c53_add (data) {
#             geo_json_da943d7a2b571cdf765a2ac0e87d0c53
#                 .addData(data);
#         }
#             geo_json_da943d7a2b571cdf765a2ac0e87d0c53_add({&quot;bbox&quot;: [13.662865290445673, 46.858175957972115, 15.130470361916801, 47.85362771191058], &quot;features&quot;: [{&quot;bbox&quot;: [13.662865290445673, 46.858175957972115, 15.130470361916801, 47.85362771191058], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.662865290445673, 47.84591482730969], [13.68758850047601, 46.858175957972115], [15.12805716115114, 46.86562824777826], [15.130470361916801, 47.85362771191058], [13.662865290445673, 47.84591482730969]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;@odata.mediaContentType&quot;: &quot;application/octet-stream&quot;, &quot;Checksum&quot;: [{&quot;Algorithm&quot;: &quot;MD5&quot;, &quot;ChecksumDate&quot;: &quot;2025-02-14T09:16:29.447185Z&quot;, &quot;Value&quot;: &quot;458b40a36510667e437038177a822575&quot;}, {&quot;Algorithm&quot;: &quot;BLAKE3&quot;, &quot;ChecksumDate&quot;: &quot;2025-02-14T09:16:31.266883Z&quot;, &quot;Value&quot;: &quot;a6166d78e0520d9115ac5cd9e18a998f13cf6bcdf899624d2e8a40ab60137409&quot;}], &quot;ContentDate&quot;: {&quot;End&quot;: &quot;2025-02-13T10:00:29.024000Z&quot;, &quot;Start&quot;: &quot;2025-02-13T10:00:29.024000Z&quot;}, &quot;ContentLength&quot;: 878344227, &quot;ContentType&quot;: &quot;application/octet-stream&quot;, &quot;EvictionDate&quot;: &quot;9999-12-31T23:59:59.999999Z&quot;, &quot;Footprint&quot;: &quot;geography\u0027SRID=4326;POLYGON ((13.662865290445673 47.84591482730969, 13.68758850047601 46.858175957972115, 15.12805716115114 46.86562824777826, 15.130470361916801 47.85362771191058, 13.662865290445673 47.84591482730969))\u0027&quot;, &quot;Id&quot;: &quot;86edd327-bbe7-457a-8ec1-07b19e8e3654&quot;, &quot;ModificationDate&quot;: &quot;2025-02-14T09:16:31.534511Z&quot;, &quot;Name&quot;: &quot;S2B_MSIL1C_20250213T100029_N0511_R122_T33TVN_20250213T115442.SAFE&quot;, &quot;Online&quot;: true, &quot;OriginDate&quot;: &quot;2025-02-13T12:24:37.000000Z&quot;, &quot;PublicationDate&quot;: &quot;2025-02-13T12:43:17.547157Z&quot;, &quot;S3Path&quot;: &quot;/eodata/Sentinel-2/MSI/L1C/2025/02/13/S2B_MSIL1C_20250213T100029_N0511_R122_T33TVN_20250213T115442.SAFE&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_da943d7a2b571cdf765a2ac0e87d0c53.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_da943d7a2b571cdf765a2ac0e87d0c53.addTo(map_180d51c6386d09835c2551aaaf6c87d1);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
s2_multiple_scenes = [
    "S2B_MSIL1C_20250213T100029_N0511_R122_T33TVN_20250213T115442",
    "S2B_MSIL2A_20250206T101109_N0511_R022_T32TQT_20250206T122414",
]

mt2 = MapTiles(s2_multiple_scenes)
mt2.query_catalog()

print(mt2.input_products)
print(mt2.catalog_entries)
print(mt2.no_data)
mt2.plot_footprints()
# Out:
# ['S2B_MSIL1C_20250213T100029_N0511_R122_T33TVN_20250213T115442', 'S2B_MSIL2A_20250206T101109_N0511_R022_T32TQT_20250206T122414']
#     @odata.mediaContentType                                    Id  \
# 0  application/octet-stream  86edd327-bbe7-457a-8ec1-07b19e8e3654
# 1  application/octet-stream  cde8f7e9-276d-41b2-a19d-73ecad583124
#
#                                                 Name  \
# 0  S2B_MSIL1C_20250213T100029_N0511_R122_T33TVN_2...
# 1  S2B_MSIL2A_20250206T101109_N0511_R022_T32TQT_2...
#
#                 ContentType  ContentLength                   OriginDate  \
# 0  application/octet-stream      878344227  2025-02-13T12:24:37.000000Z
# 1  application/octet-stream     1201759031  2025-02-06T13:07:57.000000Z
#
#                PublicationDate             ModificationDate  Online  \
# 0  2025-02-13T12:43:17.547157Z  2025-02-14T09:16:31.534511Z    True
# 1  2025-02-06T13:22:18.271274Z  2025-02-06T13:30:58.561823Z    True
#
#                   EvictionDate  \
# 0  9999-12-31T23:59:59.999999Z
# 1  9999-12-31T23:59:59.999999Z
#
#                                               S3Path  \
# 0  /eodata/Sentinel-2/MSI/L1C/2025/02/13/S2B_MSIL...
# 1  /eodata/Sentinel-2/MSI/L2A/2025/02/06/S2B_MSIL...
#
#                                             Checksum  \
# 0  [{'Value': '458b40a36510667e437038177a822575',...
# 1  [{'Value': 'b0ddd49b3292f49484589ed1187c0ed0',...
#
#                                          ContentDate  \
# 0  {'Start': '2025-02-13T10:00:29.024000Z', 'End'...
# 1  {'Start': '2025-02-06T10:11:09.025000Z', 'End'...
#
#                                            Footprint  \
# 0  geography'SRID=4326;POLYGON ((13.6628652904456...
# 1  geography'SRID=4326;POLYGON ((11.6715394263996...
#
#                                         GeoFootprint
# 0  POLYGON ((13.66287 47.84591, 13.68759 46.85818...
# 1  POLYGON ((11.67154 47.82261, 11.6222 46.83566,...
# []
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2d30003cf88059dff088a36c95cfea6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2d30003cf88059dff088a36c95cfea6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2d30003cf88059dff088a36c95cfea6 = L.map(
#                 &quot;map_c2d30003cf88059dff088a36c95cfea6&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5bf9a0e95a5af32fb4f6a9173639d427 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5bf9a0e95a5af32fb4f6a9173639d427.addTo(map_c2d30003cf88059dff088a36c95cfea6);
#
#
#             map_c2d30003cf88059dff088a36c95cfea6.fitBounds(
#                 [[46.79367068819608, 11.62219565551236], [47.85362771191058, 15.130470361916801]],
#                 {}
#             );
#
#
#
#         function geo_json_6385de168a3c726220d3987f14c19080_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6385de168a3c726220d3987f14c19080 = L.geoJson(null, {
#                 onEachFeature: geo_json_6385de168a3c726220d3987f14c19080_onEachFeature,
#
#         });
#
#         function geo_json_6385de168a3c726220d3987f14c19080_add (data) {
#             geo_json_6385de168a3c726220d3987f14c19080
#                 .addData(data);
#         }
#             geo_json_6385de168a3c726220d3987f14c19080_add({&quot;bbox&quot;: [11.62219565551236, 46.79367068819608, 15.130470361916801, 47.85362771191058], &quot;features&quot;: [{&quot;bbox&quot;: [13.662865290445673, 46.858175957972115, 15.130470361916801, 47.85362771191058], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[13.662865290445673, 47.84591482730969], [13.68758850047601, 46.858175957972115], [15.12805716115114, 46.86562824777826], [15.130470361916801, 47.85362771191058], [13.662865290445673, 47.84591482730969]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;@odata.mediaContentType&quot;: &quot;application/octet-stream&quot;, &quot;Checksum&quot;: [{&quot;Algorithm&quot;: &quot;MD5&quot;, &quot;ChecksumDate&quot;: &quot;2025-02-14T09:16:29.447185Z&quot;, &quot;Value&quot;: &quot;458b40a36510667e437038177a822575&quot;}, {&quot;Algorithm&quot;: &quot;BLAKE3&quot;, &quot;ChecksumDate&quot;: &quot;2025-02-14T09:16:31.266883Z&quot;, &quot;Value&quot;: &quot;a6166d78e0520d9115ac5cd9e18a998f13cf6bcdf899624d2e8a40ab60137409&quot;}], &quot;ContentDate&quot;: {&quot;End&quot;: &quot;2025-02-13T10:00:29.024000Z&quot;, &quot;Start&quot;: &quot;2025-02-13T10:00:29.024000Z&quot;}, &quot;ContentLength&quot;: 878344227, &quot;ContentType&quot;: &quot;application/octet-stream&quot;, &quot;EvictionDate&quot;: &quot;9999-12-31T23:59:59.999999Z&quot;, &quot;Footprint&quot;: &quot;geography\u0027SRID=4326;POLYGON ((13.662865290445673 47.84591482730969, 13.68758850047601 46.858175957972115, 15.12805716115114 46.86562824777826, 15.130470361916801 47.85362771191058, 13.662865290445673 47.84591482730969))\u0027&quot;, &quot;Id&quot;: &quot;86edd327-bbe7-457a-8ec1-07b19e8e3654&quot;, &quot;ModificationDate&quot;: &quot;2025-02-14T09:16:31.534511Z&quot;, &quot;Name&quot;: &quot;S2B_MSIL1C_20250213T100029_N0511_R122_T33TVN_20250213T115442.SAFE&quot;, &quot;Online&quot;: true, &quot;OriginDate&quot;: &quot;2025-02-13T12:24:37.000000Z&quot;, &quot;PublicationDate&quot;: &quot;2025-02-13T12:43:17.547157Z&quot;, &quot;S3Path&quot;: &quot;/eodata/Sentinel-2/MSI/L1C/2025/02/13/S2B_MSIL1C_20250213T100029_N0511_R122_T33TVN_20250213T115442.SAFE&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [11.62219565551236, 46.79367068819608, 13.135258475277471, 47.82260755999096], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[11.671539426399653, 47.82260755999096], [11.62219565551236, 46.835655727197015], [13.059029865045021, 46.79367068819608], [13.135258475277471, 47.779157072334634], [11.671539426399653, 47.82260755999096]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;@odata.mediaContentType&quot;: &quot;application/octet-stream&quot;, &quot;Checksum&quot;: [{&quot;Algorithm&quot;: &quot;MD5&quot;, &quot;ChecksumDate&quot;: &quot;2025-02-06T13:22:15.631273Z&quot;, &quot;Value&quot;: &quot;b0ddd49b3292f49484589ed1187c0ed0&quot;}, {&quot;Algorithm&quot;: &quot;BLAKE3&quot;, &quot;ChecksumDate&quot;: &quot;2025-02-06T13:22:17.370632Z&quot;, &quot;Value&quot;: &quot;b6b75ffc1936d3a82320be320e499ad5bf0ffd90e11fed836f4e4aa27564930a&quot;}], &quot;ContentDate&quot;: {&quot;End&quot;: &quot;2025-02-06T10:11:09.025000Z&quot;, &quot;Start&quot;: &quot;2025-02-06T10:11:09.025000Z&quot;}, &quot;ContentLength&quot;: 1201759031, &quot;ContentType&quot;: &quot;application/octet-stream&quot;, &quot;
